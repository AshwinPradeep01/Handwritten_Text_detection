# %% [markdown]
# <a href="https://colab.research.google.com/github/GAMEWALKER360/Handwritten_Text_detection/blob/main/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# fatal: destination path 'yolov7' already exists and is not an empty directory.

# %%
# %cd yolov7
# Out:
# /content/drive/MyDrive/yolov7

# %%
# !pip install -r requirements.txt

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# !python train.py --workers 1 --device 0 --batch-size 8  --epochs 100 --img 640  --data data/custom_data.yaml --hyp hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --name yolov7-handwritten-sign-recognition --weights yolov7.pt
# Out:
# 2023-07-14 11:52:23.805303: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-14 11:52:25.297138: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...

# %%
# !python detect.py --weights runs/train/yolov7-handwritten-sign-recognition3/weights/best.pt --source /content/skew_cor_Retail_-_MH_enterprise_orient-2[1].jpeg
# Out:
# Namespace(weights=['runs/train/yolov7-handwritten-sign-recognition3/weights/best.pt'], source='/content/skew_cor_Retail_-_MH_enterprise_orient-2[1].jpeg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
